# %% [markdown]
# ## Section 1:
# In Markdown, explain what dataset you chose and why you chose it. Include why is it meaningful to you and how you went about finding it. Then, in Python, load your dataset into a DataFrame.

# %% [markdown]
# I chose a dataset about real estate sales because I am interested in the real estate market. In the future, I would love to get into the real estate business. I searched real estate datasets on Google and found this dataset containing the sales between 2001 and 2021.

# %%
import pandas as pd
df = pd.read_csv("Real_Estate_Sales_2001-2021.csv")
df
# Out:
# C:\Users\ompat\AppData\Local\Temp\ipykernel_2560\2465290093.py:2: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Real_Estate_Sales_2001-2021.csv")
#          Serial Number  List Year Date Recorded        Town  \
# 0              2020177       2020    04/14/2021     Ansonia
# 1              2020225       2020    05/26/2021     Ansonia
# 2              2020348       2020    09/13/2021     Ansonia
# 3              2020090       2020    12/14/2020     Ansonia
# 4               200500       2020    09/07/2021        Avon
# ...                ...        ...           ...         ...
# 1054154          21073       2021    11/16/2021   Watertown
# 1054155      210900013       2021    09/20/2022    Woodbury
# 1054156      210500004       2021    05/06/2022    Woodbury
# 1054157         211130       2021    06/29/2022  West Haven
# 1054158         210374       2021    04/26/2022     Windsor
#
# ...

# %% [markdown]
# ## Section 2:
# Exploratory Data Analysis: In Markdown, explain what descriptive statistics can help you give a broad overview of the data (ex: size, shape, interesting descriptive statistics, etc.). In Python, do this exploratory data analysis.

# %% [markdown]
# Some descriptive statistics helped me find a broad overview of the data set of the difference between single-family homes and homes in general. Finding these descriptive statistics on single-family homes being sold has me wondering what the average sale price is, the average sale ratio, and other interesting statistics about sold homes.

# %%
df_ListyearHouse = df.sort_values("List Year",ascending=True)
df_ListyearHouse
# Out:
#          Serial Number  List Year Date Recorded         Town  \
# 91415            12066       2001    06/27/2002   Bridgeport
# 76169            10395       2001    09/03/2002      Madison
# 76168            11174       2001    05/10/2002      Danbury
# 76167            10060       2001    10/09/2001      Danbury
# 76166            10633       2001    06/26/2002  Glastonbury
# ...                ...        ...           ...          ...
# 1016198         210367       2021    07/14/2022    Killingly
# 1016199          21097       2021    09/08/2022   Canterbury
# 1016200         210372       2021    07/27/2022   New Canaan
# 1016189         211082       2021    08/02/2022       Hamden
# 1054158         210374       2021    04/26/2022      Windsor
#
#                          Address  Assessed Value  Sale Amount  Sales Ratio  \
# 91415             31 PRESCOTT ST         87711.0     210000.0     0.417671
# 76169              100 KELSEY PL        172900.0     754000.0     0.229310
# ...

# %%
# Filter to Single Family Homes sold 
houseTypes = df[(df["Residential Type"]) == "Single Family"]
houseTypes
# Out:
#          Serial Number  List Year Date Recorded           Town  \
# 0              2020177       2020    04/14/2021        Ansonia
# 4               200500       2020    09/07/2021           Avon
# 5               200121       2020    12/15/2020           Avon
# 6                20058       2020    06/01/2021    Barkhamsted
# 7               200046       2020    01/25/2021   Beacon Falls
# ...                ...        ...           ...            ...
# 1054151         211231       2021    09/02/2022  West Hartford
# 1054152         210282       2021    03/22/2022       Westport
# 1054153        2100471       2021    08/03/2022   Wethersfield
# 1054154          21073       2021    11/16/2021      Watertown
# 1054157         211130       2021    06/29/2022     West Haven
#
#                    Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0            323 BEAVER ST        133000.0     248400.0     0.535400
# ...

# %%
# Single Family homes greater or equal to 250000 sold 
SingleHouse = houseTypes[(houseTypes["Sale Amount"] > 275000)]
SingleHouseSaleAmount = SingleHouse
SingleHouseSaleAmount
# Out:
#          Serial Number  List Year Date Recorded           Town  \
# 4               200500       2020    09/07/2021           Avon
# 5               200121       2020    12/15/2020           Avon
# 6                20058       2020    06/01/2021    Barkhamsted
# 10               20281       2020    04/21/2021         Bethel
# 12               20423       2020    07/21/2021         Bethel
# ...                ...        ...           ...            ...
# 1054149          21113       2021    12/20/2021      Watertown
# 1054150         210778       2021    05/10/2022  West Hartford
# 1054151         211231       2021    09/02/2022  West Hartford
# 1054152         210282       2021    03/22/2022       Westport
# 1054154          21073       2021    11/16/2021      Watertown
#
#                      Address  Assessed Value  Sale Amount  Sales Ratio  \
# 4               245 NEW ROAD        217640.0     400000.0     0.544100
# ...

# %%
Value = df["Assessed Value"]
avgValue = Value.mean()
avgValue
# Out:
# 279741.56534925

# %%
SingleValue = SingleHouseSaleAmount["Assessed Value"]
avgSingleValue = SingleValue.mean()
avgSingleValue
# Out:
# 430870.356226731

# %%
Values = df["Sale Amount"]
avgValue1 = Values.mean()
avgValue1
# Out:
# 399028.6425151518

# %%
SingleValue1 = SingleHouseSaleAmount["Sale Amount"]
avgSingleValue1 = SingleValue1.mean()
avgSingleValue1
# Out:
# 672383.5920128213

# %%
Saleval = df["Assessed Value"]
stdSaleVAL = Saleval.std()
stdSaleVAL
# Out:
# 1650117.3338574858

# %%
SingleHouseSaleval = SingleHouseSaleAmount["Assessed Value"]
STDSingleHouseSaleVAL = SingleHouseSaleval.std()
STDSingleHouseSaleVAL
# Out:
# 556056.1735768885

# %%
Saleamt = df["Sale Amount"]
avgSaleAMT = Saleamt.std()
avgSaleAMT
# Out:
# 5229758.410258436

# %%
SingleHouseSaleamt = SingleHouseSaleAmount["Sale Amount"]
STDSingleHouseSaleAMT = SingleHouseSaleamt.std()
STDSingleHouseSaleAMT
# Out:
# 1107647.473827816

# %%
SingleValueSale = df["Assessed Value"]
SingleValueSaleamountvar = SingleValueSale.var()
SingleValueSaleamountvar
# Out:
# 2722887215496.937

# %%
SingleHousesaleval = SingleHouseSaleAmount["Assessed Value"]
SingleHouseAmountVAR = SingleHousesaleval.var()
SingleHouseAmountVAR
# Out:
# 309198468172.9708

# %%
SingleHousesaleamount = SingleHouseSaleAmount["Sale Amount"]
VARSingleHouseAmount = SingleHousesaleamount.var()
VARSingleHouseAmount
# Out:
# 1226882926277.1423

# %%
SingleAmountSale = df["Sale Amount"]
VRSingleValueSaleamount1 = SingleAmountSale.var()
VRSingleValueSaleamount1
# Out:
# 27350373029668.844

# %% [markdown]
# ## Section 3:
#  Exploratory Data Visualization: In Python, create at least one data visualization. This does not need to be complex, but should showcase something about your EDA or Data Science analysis. In Markdown, provide at least a two sentence summary of this result.

# %% [markdown]
# The data visualization shows the line grapgh of average residential homes (all types of homes) sold from 2001 to 2021. As shown below, there are two graphs: one showing the average of all residential types of homes sold from 2001 to 2021 and the other showing single-family homes being sold from 2001 to 2021. I chose to show my data is a line grapgh because since this is a historical data it would be much eaiser to read.

# %%
df.plot.line("List Year")
# Out:
# <Axes: xlabel='List Year'>

# %%
houseTypes.plot.line("List Year")
# Out:
# <Axes: xlabel='List Year'>

# %% [markdown]
# ## Section 4:
#  Data Science:  In Markdown, explain at least one question you have about your dataset. Clearly state the questions you have and how you plan on using Python to answer them. This may involve cleaning or selecting a subset of the data. You can use any technique you learned in DISCOVERY that is beyond simple descriptive statistics.
#
# When looking at this dataset, I had a question: what is the relationship between assessed value and sale amount in single-family homes? I plan on using the scatter plot diagram to see where most of the clusters of points will be and where the outliers stand. I plan on using regression to see the relationship between the sale amount and Assessed value to see if the sale amount had any influence based on the assessed value of the single home. Then, I will create a regression line to see how well the data follows the line of best fit based on the X and Y values, known as sale amount and assessed value.

# %%
cools = ["Assessed Value", "Sale Amount" ]
df_cools = df[cools]
df_cools.corr()
# Out:
#                 Assessed Value  Sale Amount
# Assessed Value        1.000000     0.121608
# Sale Amount           0.121608     1.000000

# %%
houseTypes.plot.scatter(x = "Assessed Value" , y = "Sale Amount")
# Out:
# <Axes: xlabel='Assessed Value', ylabel='Sale Amount'>

# %%
import seaborn as sns
sns.regplot(data=houseTypes, x="Assessed Value", y="Sale Amount", ci=None, line_kws={'color':'red'})
# Out:
# <Axes: xlabel='Assessed Value', ylabel='Sale Amount'>

# %% [markdown]
# After using the regression and regression line best of fit between assessed value and sales amount, I found a weak, positive relationship between assessed value and sale amount. I discovered that the (r) value, or coefficient, is 0.121608. Instead of using all the real estate data for all the types of homes and residential types, I chose to use only single-family homes because that's where most people looking for some residential property buy. It also eliminates any outliers that could give us an inaccurate representation of the relationships between assessed value and sale amount. I looked at the scatter plot and noticed that most of the single-family home data were mainly clustered around between 0.1 -0.5, with a few outliers. After making a regression line, I noticed that most of the points on the line are in the cluster, while the other half are either above or below the line, which does not conform to the regression line. The answer to my question is that the assessed value is unrelated to the sale amount, which means asset value is not used to predict the sale amount on single-family homes.

# %% [markdown]
# ## Section 5:
#  Overall Summary: In Markdown, summarize your dataset, findings, and visualization. A good summary shares a complete overview of your work in only 1-2 paragraphs without going low-level into the code. This might be the summary you would share in a future interview if someone asked you about "what is a data science project you did on your own?". Make sure to include at least 1-2 paragraphs for your summary (a paragraph is at least 5 sentences).

# %% [markdown]
# In my dataset about real estate, I focused on single-family homes, assessed value, and sale amount. I noticed that between 2001- 2021, there had been 1054158 single-family homes sold since then. The average assessed value for single homes was 430870.356226731, the variance for single-family homes assessed value was 309198468172.9708, and the standard deviations for single-family homes assessed value was 556056.1735768885. The average sale amount for single-family homes is 672383.5920128213, the variance for single-family home sale amount is 27350373029668.844, and the standard deviation for single-family home sale amount is 1107647.473827816.
#
# I found a weak positive relationship between assessed value and sale amount in single-family homes. I came to this conclusion by first finding the correlation between the assessed value and sale amount in single-family homes. I chose single-family homes because the average consumer will look to buy a single-family home, and many of the data points from the other types of residential properties would give me inaccurate information. I found out that the correlation was 0.121608. I looked at the scatter plot and found that the data points were all around the same region, besides a couple of outliers. Finally, I created a regression line that didn't fall. Line while only some points did fall on the line, most were either above or below the regression line, leading me to conclude that assessed value and sale amount are not related to one another in single-family homes, and it would not be a good predictor to find the value of the single-family home.
